# %%
import pickle

# %%
def analyze_deep_player_actions(game_state_file, num_games=1):
    with open(game_state_file, 'rb') as f:
        game_state_batches = pickle.load(f)
    
    game_state_batches = game_state_batches[:num_games]
    for i, gsb in enumerate(game_state_batches):
        print(f"{'-'*80}\nGame: {i+1}\n{'-'*80}\n")
        player = list(gsb.keys())[0]
        game_states = gsb[player]
        for round, game_state in enumerate(game_states):
            pre_stack, post_stack, stack_delta, gs = game_state
            print(f"Round: {round}")
            print(f"Pre-Round Stack: {pre_stack}")
            print(f"Post-Round Stack: {post_stack}")
            print(f"Stack delta: {stack_delta:.4f}")

            print("Game states and actions within round:\n")
            for game_states_round in gs:
                game_state_, action_probs, raise_ratio, action = game_states_round

                print(f"\nState:\n{game_state_}")
                print(f"Action probs: {action_probs}")
                print(f"Raise Ratio: {raise_ratio:.4f}")
                print(f"Action Taken: {action}")

            print(f"{'-'*60}\n\n")

# %%
analyze_deep_player_actions('game_state_batches_PlayerRandom_2_PlayerDeepAgent_2_1000.pkl', num_games=3) # NOTE output is truncated in nb, can see in text editor
# Out:
# --------------------------------------------------------------------------------
# Game: 1
# --------------------------------------------------------------------------------
#
# Round: 0
# Pre-Round Stack: 395
# Post-Round Stack: 1023
# Stack delta: 1.5899
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 253
# min_bet_to_continue: 233
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 395
# spots_left_bb: 2
# cards: (8♣, 2♣)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 162
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 228)]
#
# in_game: True
# stack_size: 390
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.6485103  0.03226206 0.31922767]
# Raise Ratio: 1.5026
# Action Taken: (<Action.RAISE: 2>, 147)
# ------------------------------------------------------------
#
#
# Round: 1
# Pre-Round Stack: 1023
# Post-Round Stack: 862
# Stack delta: -0.1574
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 107
# min_bet_to_continue: 92
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 1023
# spots_left_bb: 2
# cards: (9♥, 5♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 152
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 10
# spots_left_bb: 3
# cards: None
# history: []
#
# in_game: True
# stack_size: 308
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 82)]
#
# ==========================
#
# Action probs: [0.59239656 0.03513437 0.3724691 ]
# Raise Ratio: 1.5033
# Action Taken: (<Action.RAISE: 2>, 69)
#
# State:
# stage: Stage.FLOP
# pot_size: 419
# min_bet_to_continue: 0
# community cards: [4♣, 8♠, 7♠]
#
# ====== my player ======
# in_game: True
# stack_size: 862
# spots_left_bb: 1
# cards: (9♥, 5♦)
# history: [(<Action.RAISE: 2>, 69)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 151), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [0.20718877 0.44459948 0.34821174]
# Raise Ratio: 0.5461
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.TURN
# pot_size: 419
# min_bet_to_continue: 0
# community cards: [4♣, 8♠, 7♠, J♠]
#
# ====== my player ======
# in_game: True
# stack_size: 862
# spots_left_bb: 1
# cards: (9♥, 5♦)
# history: [(<Action.RAISE: 2>, 69), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 151), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [0.2112582  0.48558798 0.30315378]
# Raise Ratio: 0.7599
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.RIVER
# pot_size: 419
# min_bet_to_continue: 0
# community cards: [4♣, 8♠, 7♠, J♠, K♥]
#
# ====== my player ======
# in_game: True
# stack_size: 862
# spots_left_bb: 1
# cards: (9♥, 5♦)
# history: [(<Action.RAISE: 2>, 69), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 151), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [0.27097678 0.44745904 0.28156412]
# Raise Ratio: 0.9508
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 2
# Pre-Round Stack: 862
# Post-Round Stack: 862
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 862
# spots_left_bb: 1
# cards: (6♦, 5♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 415
# spots_left_bb: 3
# cards: None
# history: []
#
# in_game: True
# stack_size: 10
# spots_left_bb: 2
# cards: None
# history: []
#
# in_game: True
# stack_size: 298
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.8880993  0.01686434 0.09503635]
# Raise Ratio: 1.5308
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 3
# Pre-Round Stack: 852
# Post-Round Stack: 867
# Stack delta: 0.0176
# Game states and actions within round:
#
# ------------------------------------------------------------
#
#
# Round: 4
# Pre-Round Stack: 862
# Post-Round Stack: 1262
# Stack delta: 0.4640
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 25
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 862
# spots_left_bb: 1
# cards: (9♦, J♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 405
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 10)]
#
# ==========================
#
# Action probs: [0.5651444  0.0369117  0.39794385]
# Raise Ratio: 1.5139
# Action Taken: (<Action.RAISE: 2>, 33)
#
# State:
# stage: Stage.PREFLOP
# pot_size: 313
# min_bet_to_continue: 217
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 824
# spots_left_bb: 1
# cards: (9♦, J♥)
# history: [(<Action.RAISE: 2>, 33)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 155
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 10), (<Action.RAISE: 2>, 217)]
#
# ==========================
#
# Action probs: [0.4237413  0.04290816 0.5333506 ]
# Raise Ratio: 1.5160
# Action Taken: (<Action.RAISE: 2>, 258)
# ------------------------------------------------------------
#
#
# Round: 5
# Pre-Round Stack: 1262
# Post-Round Stack: 1262
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 1262
# spots_left_bb: 1
# cards: (4♦, 2♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 25
# spots_left_bb: 2
# cards: None
# history: []
#
# in_game: True
# stack_size: 298
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.919643   0.01380617 0.06655084]
# Raise Ratio: 1.5366
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 6
# Pre-Round Stack: 1252
# Post-Round Stack: 1252
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 20
# min_bet_to_continue: 0
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 1252
# spots_left_bb: 0
# cards: (A♠, 8♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 303
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 5)]
#
# ==========================
#
# Action probs: [0.9271515  0.0305541  0.04229446]
# Raise Ratio: 1.9426
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 7
# Pre-Round Stack: 1247
# Post-Round Stack: 1247
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 25
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 1247
# spots_left_bb: 2
# cards: (A♥, 3♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 15
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 313
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 10)]
#
# ==========================
#
# Action probs: [0.9319253  0.02238262 0.04569209]
# Raise Ratio: 1.7845
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 8
# Pre-Round Stack: 1247
# Post-Round Stack: 1262
# Stack delta: 0.0120
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 1247
# spots_left_bb: 1
# cards: (J♣, J♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 10
# spots_left_bb: 2
# cards: None
# history: []
#
# in_game: True
# stack_size: 328
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.02517493 0.03300408 0.9418209 ]
# Raise Ratio: 1.4861
# Action Taken: (<Action.RAISE: 2>, 12)
# ------------------------------------------------------------
#
#
# Round: 9
# Pre-Round Stack: 1252
# Post-Round Stack: 1590
# Stack delta: 0.2700
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 248
# min_bet_to_continue: 228
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 1252
# spots_left_bb: 0
# cards: (Q♦, 2♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 90
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 228)]
#
# ==========================
#
# Action probs: [0.312739   0.04551958 0.64174145]
# Raise Ratio: 1.5023
# Action Taken: (<Action.RAISE: 2>, 145)
# ------------------------------------------------------------
#
#
# Round: 10
# Pre-Round Stack: 1585
# Post-Round Stack: 1595
# Stack delta: 0.0063
# Game states and actions within round:
#
# ------------------------------------------------------------
#
#
# Round: 11
# Pre-Round Stack: 1585
# Post-Round Stack: 1600
# Stack delta: 0.0095
# Game states and actions within round:
#
# ------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Game: 2
# --------------------------------------------------------------------------------
#
# Round: 0
# Pre-Round Stack: 400
# Post-Round Stack: 400
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 400
# spots_left_bb: 1
# cards: (3♦, 7♣)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 390
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 395
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.85364544 0.01956505 0.12678955]
# Raise Ratio: 1.5272
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 1
# Pre-Round Stack: 400
# Post-Round Stack: 400
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 400
# spots_left_bb: 1
# cards: (3♣, 9♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 385
# spots_left_bb: 3
# cards: None
# history: []
#
# in_game: True
# stack_size: 390
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 410
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.74055094 0.02710291 0.23234612]
# Raise Ratio: 1.5191
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 2
# Pre-Round Stack: 390
# Post-Round Stack: 390
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 57
# min_bet_to_continue: 32
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 390
# spots_left_bb: 0
# cards: (5♦, 7♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 343
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 32)]
#
# ==========================
#
# Action probs: [0.89935887 0.01557614 0.08506493]
# Raise Ratio: 1.5794
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 3
# Pre-Round Stack: 385
# Post-Round Stack: 283
# Stack delta: -0.2649
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 25
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 385
# spots_left_bb: 2
# cards: (6♣, 6♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 390
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 10)]
#
# in_game: True
# stack_size: 415
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.18621436 0.22813848 0.5856471 ]
# Raise Ratio: 2.0974
# Action Taken: (<Action.CHECK_CALL: 1>, 5)
#
# State:
# stage: Stage.FLOP
# pot_size: 30
# min_bet_to_continue: 0
# community cards: [10♥, A♣, 7♥]
#
# ====== my player ======
# in_game: True
# stack_size: 380
# spots_left_bb: 2
# cards: (6♣, 6♦)
# history: [(<Action.CHECK_CALL: 1>, 5)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 390
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 10)]
#
# in_game: True
# stack_size: 415
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [3.1873354e-04 9.7516519e-01 2.4516093e-02]
# Raise Ratio: 0.5081
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.TURN
# pot_size: 30
# min_bet_to_continue: 0
# community cards: [10♥, A♣, 7♥, Q♣]
#
# ====== my player ======
# in_game: True
# stack_size: 380
# spots_left_bb: 2
# cards: (6♣, 6♦)
# history: [(<Action.CHECK_CALL: 1>, 5), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 390
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 10), (<Action.CHECK_CALL: 1>, 0)]
#
# in_game: True
# stack_size: 415
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [6.3325989e-04 8.9583963e-01 1.0352710e-01]
# Raise Ratio: 0.5731
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.RIVER
# pot_size: 30
# min_bet_to_continue: 0
# community cards: [10♥, A♣, 7♥, Q♣, 10♣]
#
# ====== my player ======
# in_game: True
# stack_size: 380
# spots_left_bb: 2
# cards: (6♣, 6♦)
# history: [(<Action.CHECK_CALL: 1>, 5), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 390
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 10), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
#
# in_game: True
# stack_size: 415
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [2.1759946e-04 6.4254969e-01 3.5723272e-01]
# Raise Ratio: 0.6618
# Action Taken: (<Action.RAISE: 2>, 20)
#
# State:
# stage: Stage.RIVER
# pot_size: 244
# min_bet_to_continue: 77
# community cards: [10♥, A♣, 7♥, Q♣, 10♣]
#
# ====== my player ======
# in_game: True
# stack_size: 360
# spots_left_bb: 2
# cards: (6♣, 6♦)
# history: [(<Action.CHECK_CALL: 1>, 5), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0), (<Action.RAISE: 2>, 20)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 293
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 10), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 97)]
#
# in_game: True
# stack_size: 318
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0), (<Action.RAISE: 2>, 77)]
#
# ==========================
#
# Action probs: [0.00663439 0.7033699  0.28999567]
# Raise Ratio: 0.5786
# Action Taken: (<Action.CHECK_CALL: 1>, 77)
# ------------------------------------------------------------
#
#
# Round: 4
# Pre-Round Stack: 283
# Post-Round Stack: 96
# Stack delta: -0.6608
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 283
# spots_left_bb: 1
# cards: (J♠, J♣)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 283
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 634
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.02222031 0.03114471 0.946635  ]
# Raise Ratio: 1.4879
# Action Taken: (<Action.RAISE: 2>, 12)
#
# State:
# stage: Stage.PREFLOP
# pot_size: 396
# min_bet_to_continue: 165
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 261
# spots_left_bb: 1
# cards: (J♠, J♣)
# history: [(<Action.RAISE: 2>, 12)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 106
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 177)]
#
# in_game: True
# stack_size: 452
# spots_left_bb: 2
# cards: None
# history: [(<Action.RAISE: 2>, 165)]
#
# ==========================
#
# Action probs: [0.02143648 0.03062681 0.9479368 ]
# Raise Ratio: 0.6591
# Action Taken: (<Action.RAISE: 2>, 96)
# ------------------------------------------------------------
#
#
# Round: 5
# Pre-Round Stack: 96
# Post-Round Stack: 96
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 96
# spots_left_bb: 1
# cards: (J♦, 10♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 662
# spots_left_bb: 3
# cards: None
# history: []
#
# in_game: True
# stack_size: 375
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 452
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.43949407 0.04227992 0.518226  ]
# Raise Ratio: 1.5153
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 6
# Pre-Round Stack: 86
# Post-Round Stack: 86
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 773
# min_bet_to_continue: 365
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 86
# spots_left_bb: 0
# cards: (J♥, 3♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 685
# spots_left_bb: 2
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 194)]
#
# in_game: True
# stack_size: 56
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 184)]
#
# ==========================
#
# Action probs: [0.8914758 0.1085242 0.       ]
# Raise Ratio: 0.1113
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 7
# Pre-Round Stack: 86
# Post-Round Stack: 86
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 86
# spots_left_bb: 1
# cards: (9♠, 3♣)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 819
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 680
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.65923715 0.03212572 0.3086371 ]
# Raise Ratio: 1.5166
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 8
# Pre-Round Stack: 76
# Post-Round Stack: 76
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 666
# min_bet_to_continue: 641
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 76
# spots_left_bb: 0
# cards: (6♣, 5♣)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 44
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 641)]
#
# ==========================
#
# Action probs: [0.97296876 0.02703116 0.        ]
# Raise Ratio: 0.1141
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 9
# Pre-Round Stack: 71
# Post-Round Stack: 86
# Stack delta: 0.2113
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 71
# spots_left_bb: 1
# cards: (5♥, 5♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 700
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.02892595 0.03480516 0.9362689 ]
# Raise Ratio: 1.4859
# Action Taken: (<Action.RAISE: 2>, 17)
# ------------------------------------------------------------
#
#
# Round: 10
# Pre-Round Stack: 86
# Post-Round Stack: 86
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 86
# spots_left_bb: 1
# cards: (10♠, 7♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 804
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 695
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.5473467  0.03767402 0.41497934]
# Raise Ratio: 1.5135
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 11
# Pre-Round Stack: 76
# Post-Round Stack: 91
# Stack delta: 0.1974
# Game states and actions within round:
#
# ------------------------------------------------------------
#
#
# Round: 12
# Pre-Round Stack: 86
# Post-Round Stack: 86
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 38
# min_bet_to_continue: 18
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 86
# spots_left_bb: 2
# cards: (K♥, 6♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 776
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 13)]
#
# in_game: True
# stack_size: 700
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.61681783 0.2633649  0.11981725]
# Raise Ratio: 2.2632
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 13
# Pre-Round Stack: 86
# Post-Round Stack: 86
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 86
# spots_left_bb: 1
# cards: (2♠, 9♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 804
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 695
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.66024995 0.03206841 0.3076816 ]
# Raise Ratio: 1.5166
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 14
# Pre-Round Stack: 76
# Post-Round Stack: 91
# Stack delta: 0.1974
# Game states and actions within round:
#
# ------------------------------------------------------------
#
#
# Round: 15
# Pre-Round Stack: 86
# Post-Round Stack: 182
# Stack delta: 1.1163
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 86
# spots_left_bb: 1
# cards: (9♠, A♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 700
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.27677572 0.04832296 0.67490137]
# Raise Ratio: 1.5212
# Action Taken: (<Action.RAISE: 2>, 18)
#
# State:
# stage: Stage.FLOP
# pot_size: 56
# min_bet_to_continue: 0
# community cards: [5♣, K♠, 9♦]
#
# ====== my player ======
# in_game: True
# stack_size: 63
# spots_left_bb: 1
# cards: (9♠, A♠)
# history: [(<Action.RAISE: 2>, 18)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 682
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 18)]
#
# ==========================
#
# Action probs: [0.00458856 0.9027185  0.09269293]
# Raise Ratio: 0.4790
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.TURN
# pot_size: 56
# min_bet_to_continue: 0
# community cards: [5♣, K♠, 9♦, K♦]
#
# ====== my player ======
# in_game: True
# stack_size: 63
# spots_left_bb: 1
# cards: (9♠, A♠)
# history: [(<Action.RAISE: 2>, 18), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 682
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 18), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [0.00175592 0.7837282  0.21451588]
# Raise Ratio: 0.4924
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.RIVER
# pot_size: 56
# min_bet_to_continue: 0
# community cards: [5♣, K♠, 9♦, K♦, 4♣]
#
# ====== my player ======
# in_game: True
# stack_size: 63
# spots_left_bb: 1
# cards: (9♠, A♠)
# history: [(<Action.RAISE: 2>, 18), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 682
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 18), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [0.00229008 0.6687319  0.32897794]
# Raise Ratio: 0.6032
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.RIVER
# pot_size: 216
# min_bet_to_continue: 160
# community cards: [5♣, K♠, 9♦, K♦, 4♣]
#
# ====== my player ======
# in_game: True
# stack_size: 63
# spots_left_bb: 1
# cards: (9♠, A♠)
# history: [(<Action.RAISE: 2>, 18), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 522
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 18), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0), (<Action.RAISE: 2>, 160)]
#
# ==========================
#
# Action probs: [0.01120047 0.9887995  0.        ]
# Raise Ratio: 0.2917
# Action Taken: (<Action.CHECK_CALL: 1>, 63)
# ------------------------------------------------------------
#
#
# Round: 16
# Pre-Round Stack: 182
# Post-Round Stack: 159
# Stack delta: -0.1264
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 182
# spots_left_bb: 1
# cards: (J♦, 8♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 789
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 614
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.46612543 0.04115216 0.49272248]
# Raise Ratio: 1.5140
# Action Taken: (<Action.RAISE: 2>, 13)
#
# State:
# stage: Stage.PREFLOP
# pot_size: 585
# min_bet_to_continue: 339
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 159
# spots_left_bb: 1
# cards: (J♦, 8♦)
# history: [(<Action.RAISE: 2>, 13)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 437
# spots_left_bb: 0
# cards: None
# history: [(<Action.RAISE: 2>, 162)]
#
# in_game: True
# stack_size: 419
# spots_left_bb: 2
# cards: None
# history: [(<Action.RAISE: 2>, 177)]
#
# ==========================
#
# Action probs: [0.90555286 0.09444717 0.        ]
# Raise Ratio: 0.2718
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 17
# Pre-Round Stack: 149
# Post-Round Stack: 98
# Stack delta: -0.3423
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 30
# min_bet_to_continue: 0
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 149
# spots_left_bb: 0
# cards: (5♣, A♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 427
# spots_left_bb: 2
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 5)]
#
# in_game: True
# stack_size: 994
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 10)]
#
# ==========================
#
# Action probs: [0.06898707 0.64173985 0.28927302]
# Raise Ratio: 1.6838
# Action Taken: (<Action.RAISE: 2>, 51)
#
# State:
# stage: Stage.PREFLOP
# pot_size: 444
# min_bet_to_continue: 312
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 98
# spots_left_bb: 0
# cards: (5♣, A♦)
# history: [(<Action.RAISE: 2>, 51)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 631
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 10), (<Action.RAISE: 2>, 312)]
#
# ==========================
#
# Action probs: [0.8405958 0.1594042 0.       ]
# Raise Ratio: 0.2207
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 18
# Pre-Round Stack: 93
# Post-Round Stack: 70
# Stack delta: -0.2473
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 93
# spots_left_bb: 1
# cards: (10♣, A♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1065
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.27708554 0.04831043 0.67460406]
# Raise Ratio: 1.5212
# Action Taken: (<Action.RAISE: 2>, 18)
#
# State:
# stage: Stage.PREFLOP
# pot_size: 443
# min_bet_to_continue: 387
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 70
# spots_left_bb: 1
# cards: (10♣, A♦)
# history: [(<Action.RAISE: 2>, 18)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 660
# spots_left_bb: 0
# cards: None
# history: [(<Action.RAISE: 2>, 387)]
#
# ==========================
#
# Action probs: [0.84684134 0.15315868 0.        ]
# Raise Ratio: 0.1580
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 19
# Pre-Round Stack: 70
# Post-Round Stack: 47
# Stack delta: -0.3286
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 70
# spots_left_bb: 1
# cards: (3♣, A♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 417
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 1098
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.27738225 0.04829644 0.67432135]
# Raise Ratio: 1.5212
# Action Taken: (<Action.RAISE: 2>, 13)
#
# State:
# stage: Stage.PREFLOP
# pot_size: 606
# min_bet_to_continue: 550
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 47
# spots_left_bb: 0
# cards: (3♣, A♠)
# history: [(<Action.RAISE: 2>, 13)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 530
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 550)]
#
# ==========================
#
# Action probs: [0.8408494  0.15915059 0.        ]
# Raise Ratio: 0.0776
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 20
# Pre-Round Stack: 37
# Post-Round Stack: 57
# Stack delta: 0.5405
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 20
# min_bet_to_continue: 0
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 37
# spots_left_bb: 0
# cards: (5♦, 5♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 407
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 5)]
#
# ==========================
#
# Action probs: [0.12595904 0.45211768 0.42192325]
# Raise Ratio: 1.8500
# Action Taken: (<Action.RAISE: 2>, 37)
# ------------------------------------------------------------
#
#
# Round: 21
# Pre-Round Stack: 52
# Post-Round Stack: 52
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 52
# spots_left_bb: 1
# cards: (2♥, 4♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1126
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.8855882  0.01708014 0.09733159]
# Raise Ratio: 1.5304
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 22
# Pre-Round Stack: 52
# Post-Round Stack: 29
# Stack delta: -0.4423
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 52
# spots_left_bb: 1
# cards: (A♠, 10♣)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 397
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 1136
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.27339223 0.04846269 0.6781452 ]
# Raise Ratio: 1.5215
# Action Taken: (<Action.RAISE: 2>, 13)
#
# State:
# stage: Stage.PREFLOP
# pot_size: 463
# min_bet_to_continue: 407
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 29
# spots_left_bb: 0
# cards: (A♠, 10♣)
# history: [(<Action.RAISE: 2>, 13)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 711
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 407)]
#
# ==========================
#
# Action probs: [0.8406012  0.15939881 0.        ]
# Raise Ratio: 0.0626
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 23
# Pre-Round Stack: 19
# Post-Round Stack: 19
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 273
# min_bet_to_continue: 248
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 19
# spots_left_bb: 0
# cards: (3♥, J♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 916
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 248)]
#
# ==========================
#
# Action probs: [0.8892419 0.1107581 0.       ]
# Raise Ratio: 0.0696
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 24
# Pre-Round Stack: 14
# Post-Round Stack: 14
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 38
# min_bet_to_continue: 18
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 14
# spots_left_bb: 2
# cards: (3♥, 8♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 369
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 13)]
#
# in_game: True
# stack_size: 1179
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.98532367 0.01467641 0.        ]
# Raise Ratio: 0.3684
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 25
# Pre-Round Stack: 14
# Post-Round Stack: 14
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 14
# spots_left_bb: 1
# cards: (J♣, A♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 359
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 1212
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.8472192  0.15278076 0.        ]
# Raise Ratio: 0.9333
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 26
# Pre-Round Stack: 4
# Post-Round Stack: 4
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 38
# min_bet_to_continue: 18
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 4
# spots_left_bb: 0
# cards: (2♥, 8♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 346
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 18)]
#
# ==========================
#
# Action probs: [0.98488945 0.01511055 0.        ]
# Raise Ratio: 0.1053
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Game: 3
# --------------------------------------------------------------------------------
#
# Round: 0
# Pre-Round Stack: 400
# Post-Round Stack: 952
# Stack delta: 1.3800
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 175
# min_bet_to_continue: 160
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 400
# spots_left_bb: 2
# cards: (7♣, 7♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 240
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 150)]
#
# in_game: True
# stack_size: 395
# spots_left_bb: 3
# cards: None
# history: []
#
# in_game: True
# stack_size: 390
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.02361046 0.03134577 0.94504374]
# Raise Ratio: 1.4679
# Action Taken: (<Action.RAISE: 2>, 97)
#
# State:
# stage: Stage.FLOP
# pot_size: 679
# min_bet_to_continue: 0
# community cards: [3♦, Q♥, 10♥]
#
# ====== my player ======
# in_game: True
# stack_size: 143
# spots_left_bb: 1
# cards: (7♣, 7♥)
# history: [(<Action.RAISE: 2>, 97)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 143
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 247), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [0.11805998 0.6343511  0.24758887]
# Raise Ratio: 0.2106
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.TURN
# pot_size: 734
# min_bet_to_continue: 55
# community cards: [3♦, Q♥, 10♥, 3♣]
#
# ====== my player ======
# in_game: True
# stack_size: 143
# spots_left_bb: 1
# cards: (7♣, 7♥)
# history: [(<Action.RAISE: 2>, 97), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 88
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 247), (<Action.CHECK_CALL: 1>, 0), (<Action.RAISE: 2>, 55)]
#
# ==========================
#
# Action probs: [0.04199313 0.6724916  0.28551525]
# Raise Ratio: 0.1948
# Action Taken: (<Action.CHECK_CALL: 1>, 55)
#
# State:
# stage: Stage.RIVER
# pot_size: 864
# min_bet_to_continue: 75
# community cards: [3♦, Q♥, 10♥, 3♣, 4♦]
#
# ====== my player ======
# in_game: True
# stack_size: 88
# spots_left_bb: 1
# cards: (7♣, 7♥)
# history: [(<Action.RAISE: 2>, 97), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 55)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 13
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 247), (<Action.CHECK_CALL: 1>, 0), (<Action.RAISE: 2>, 55), (<Action.RAISE: 2>, 75)]
#
# ==========================
#
# Action probs: [0.05838048 0.6697678  0.27185172]
# Raise Ratio: 0.1019
# Action Taken: (<Action.CHECK_CALL: 1>, 75)
# ------------------------------------------------------------
#
#
# Round: 1
# Pre-Round Stack: 952
# Post-Round Stack: 952
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 952
# spots_left_bb: 1
# cards: (4♥, J♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 230
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 395
# spots_left_bb: 2
# cards: None
# history: []
#
# in_game: True
# stack_size: 8
# spots_left_bb: 3
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.69578356 0.03000313 0.27421334]
# Raise Ratio: 1.5176
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 2
# Pre-Round Stack: 942
# Post-Round Stack: 942
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 56
# min_bet_to_continue: 13
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 942
# spots_left_bb: 0
# cards: (2♣, 4♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 222
# spots_left_bb: 2
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 18)]
#
# in_game: True
# stack_size: 372
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 13)]
#
# ==========================
#
# Action probs: [0.968978   0.00910868 0.02191343]
# Raise Ratio: 1.7248
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 3
# Pre-Round Stack: 937
# Post-Round Stack: 969
# Stack delta: 0.0342
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 64
# min_bet_to_continue: 36
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 937
# spots_left_bb: 2
# cards: (10♠, 3♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 237
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 31)]
#
# in_game: True
# stack_size: 362
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.682148   0.03037973 0.28747228]
# Raise Ratio: 1.5275
# Action Taken: (<Action.RAISE: 2>, 62)
# ------------------------------------------------------------
#
#
# Round: 4
# Pre-Round Stack: 969
# Post-Round Stack: 791
# Stack delta: -0.1837
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 83
# min_bet_to_continue: 68
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 969
# spots_left_bb: 2
# cards: (10♣, J♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 169
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 58)]
#
# in_game: True
# stack_size: 357
# spots_left_bb: 3
# cards: None
# history: []
#
# in_game: True
# stack_size: 22
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.374853   0.04380923 0.58133775]
# Raise Ratio: 1.5022
# Action Taken: (<Action.RAISE: 2>, 57)
#
# State:
# stage: Stage.FLOP
# pot_size: 340
# min_bet_to_continue: 53
# community cards: [K♠, A♦, A♣]
#
# ====== my player ======
# in_game: True
# stack_size: 844
# spots_left_bb: 1
# cards: (10♣, J♠)
# history: [(<Action.RAISE: 2>, 57)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 59
# spots_left_bb: 0
# cards: None
# history: [(<Action.RAISE: 2>, 58), (<Action.CHECK_CALL: 1>, 57), (<Action.RAISE: 2>, 53)]
#
# ==========================
#
# Action probs: [0.11725295 0.5497243  0.33302274]
# Raise Ratio: 0.4540
# Action Taken: (<Action.CHECK_CALL: 1>, 53)
#
# State:
# stage: Stage.TURN
# pot_size: 410
# min_bet_to_continue: 17
# community cards: [K♠, A♦, A♣, 6♥]
#
# ====== my player ======
# in_game: True
# stack_size: 791
# spots_left_bb: 1
# cards: (10♣, J♠)
# history: [(<Action.RAISE: 2>, 57), (<Action.CHECK_CALL: 1>, 53)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 42
# spots_left_bb: 0
# cards: None
# history: [(<Action.RAISE: 2>, 58), (<Action.CHECK_CALL: 1>, 57), (<Action.RAISE: 2>, 53), (<Action.RAISE: 2>, 17)]
#
# ==========================
#
# Action probs: [0.15647915 0.56835514 0.27516568]
# Raise Ratio: 0.6679
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 5
# Pre-Round Stack: 791
# Post-Round Stack: 791
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 791
# spots_left_bb: 1
# cards: (J♦, 7♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 341
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 357
# spots_left_bb: 2
# cards: None
# history: []
#
# in_game: True
# stack_size: 96
# spots_left_bb: 3
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.6488882  0.03272999 0.3183819 ]
# Raise Ratio: 1.5162
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 6
# Pre-Round Stack: 781
# Post-Round Stack: 781
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 103
# min_bet_to_continue: 53
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 781
# spots_left_bb: 0
# cards: (3♣, 10♣)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 218
# spots_left_bb: 2
# cards: None
# history: [(<Action.RAISE: 2>, 33)]
#
# in_game: True
# stack_size: 141
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 20)]
#
# ==========================
#
# Action probs: [0.6298244  0.03337932 0.33679625]
# Raise Ratio: 1.5230
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 7
# Pre-Round Stack: 776
# Post-Round Stack: 776
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 776
# spots_left_bb: 1
# cards: (7♦, 2♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 347
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.8730971  0.01816059 0.10874224]
# Raise Ratio: 1.5286
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 8
# Pre-Round Stack: 776
# Post-Round Stack: 325
# Stack delta: -0.5812
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 325
# min_bet_to_continue: 310
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 776
# spots_left_bb: 2
# cards: (2♠, 8♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 141
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 300)]
#
# in_game: True
# stack_size: 357
# spots_left_bb: 3
# cards: None
# history: []
#
# in_game: True
# stack_size: 1
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.6507656  0.03212919 0.31710523]
# Raise Ratio: 1.5025
# Action Taken: (<Action.RAISE: 2>, 178)
# ------------------------------------------------------------
#
#
# Round: 9
# Pre-Round Stack: 325
# Post-Round Stack: 325
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 325
# spots_left_bb: 1
# cards: (4♠, 9♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 870
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 357
# spots_left_bb: 2
# cards: None
# history: []
#
# in_game: True
# stack_size: 33
# spots_left_bb: 3
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.72142524 0.0283658  0.2502089 ]
# Raise Ratio: 1.5185
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 10
# Pre-Round Stack: 320
# Post-Round Stack: 320
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 733
# min_bet_to_continue: 720
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 320
# spots_left_bb: 1
# cards: (3♥, 9♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 547
# spots_left_bb: 0
# cards: None
# history: [(<Action.RAISE: 2>, 715)]
#
# ==========================
#
# Action probs: [0.9501199  0.04988009 0.        ]
# Raise Ratio: 0.4366
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 11
# Pre-Round Stack: 320
# Post-Round Stack: 320
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 320
# spots_left_bb: 1
# cards: (2♦, 3♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1261
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 4
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.9047839  0.01530531 0.0799107 ]
# Raise Ratio: 1.5336
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 12
# Pre-Round Stack: 310
# Post-Round Stack: 322
# Stack delta: 0.0387
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 24
# min_bet_to_continue: 0
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 310
# spots_left_bb: 0
# cards: (6♠, J♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1266
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 5)]
#
# ==========================
#
# Action probs: [0.00934313 0.56204003 0.42861685]
# Raise Ratio: 1.5957
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.FLOP
# pot_size: 24
# min_bet_to_continue: 0
# community cards: [5♦, 2♦, K♥]
#
# ====== my player ======
# in_game: True
# stack_size: 310
# spots_left_bb: 0
# cards: (6♠, J♠)
# history: [(<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1266
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 5), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [0.02229213 0.75499034 0.22271752]
# Raise Ratio: 0.6450
# Action Taken: (<Action.RAISE: 2>, 15)
# ------------------------------------------------------------
#
#
# Round: 13
# Pre-Round Stack: 317
# Post-Round Stack: 317
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 584
# min_bet_to_continue: 564
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 317
# spots_left_bb: 2
# cards: (5♥, 3♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 697
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 559)]
#
# in_game: True
# stack_size: 2
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.97701824 0.02298185 0.        ]
# Raise Ratio: 0.5428
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 14
# Pre-Round Stack: 317
# Post-Round Stack: 317
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 12
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 317
# spots_left_bb: 1
# cards: (K♦, 10♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1271
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.3427314  0.04534694 0.61192167]
# Raise Ratio: 1.6667
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 15
# Pre-Round Stack: 307
# Post-Round Stack: 322
# Stack delta: 0.0489
# Game states and actions within round:
#
# ------------------------------------------------------------
#
#
# Round: 16
# Pre-Round Stack: 317
# Post-Round Stack: 318
# Stack delta: 0.0032
# Game states and actions within round:
#
# ------------------------------------------------------------
#
#
# Round: 17
# Pre-Round Stack: 318
# Post-Round Stack: 318
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 10
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 318
# spots_left_bb: 1
# cards: (2♠, 9♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1264
# spots_left_bb: 0
# cards: None
# history: []
#
# in_game: True
# stack_size: 3
# spots_left_bb: 2
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.7214928  0.02836121 0.25014597]
# Raise Ratio: 1.5185
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 18
# Pre-Round Stack: 313
# Post-Round Stack: 313
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 313
# spots_left_bb: 1
# cards: (2♠, 3♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1272
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.90456533 0.01532644 0.08010818]
# Raise Ratio: 1.5336
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 19
# Pre-Round Stack: 303
# Post-Round Stack: 323
# Stack delta: 0.0660
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 20
# min_bet_to_continue: 0
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 303
# spots_left_bb: 0
# cards: (8♣, 10♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1277
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 5)]
#
# ==========================
#
# Action probs: [0.00308169 0.6007559  0.39616248]
# Raise Ratio: 1.4371
# Action Taken: (<Action.RAISE: 2>, 29)
# ------------------------------------------------------------
#
#
# Round: 20
# Pre-Round Stack: 318
# Post-Round Stack: 318
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 318
# spots_left_bb: 1
# cards: (5♥, 9♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1267
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.7185746  0.02854958 0.25287586]
# Raise Ratio: 1.5184
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 21
# Pre-Round Stack: 308
# Post-Round Stack: 65
# Stack delta: -0.7890
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 20
# min_bet_to_continue: 0
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 308
# spots_left_bb: 0
# cards: (6♥, J♠)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1272
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 5)]
#
# ==========================
#
# Action probs: [0.00316269 0.5986753  0.398162  ]
# Raise Ratio: 1.4493
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.FLOP
# pot_size: 263
# min_bet_to_continue: 243
# community cards: [2♣, 2♠, 4♠]
#
# ====== my player ======
# in_game: True
# stack_size: 308
# spots_left_bb: 0
# cards: (6♥, J♠)
# history: [(<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1029
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 5), (<Action.RAISE: 2>, 243)]
#
# ==========================
#
# Action probs: [0.23924345 0.45702845 0.30372813]
# Raise Ratio: 0.9620
# Action Taken: (<Action.CHECK_CALL: 1>, 243)
#
# State:
# stage: Stage.TURN
# pot_size: 506
# min_bet_to_continue: 0
# community cards: [2♣, 2♠, 4♠, 4♣]
#
# ====== my player ======
# in_game: True
# stack_size: 65
# spots_left_bb: 0
# cards: (6♥, J♠)
# history: [(<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 243)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1029
# spots_left_bb: 1
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 5), (<Action.RAISE: 2>, 243), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [0.18581767 0.4928121  0.32137015]
# Raise Ratio: 0.1285
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 22
# Pre-Round Stack: 60
# Post-Round Stack: 60
# Stack delta: 0.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 60
# spots_left_bb: 1
# cards: (Q♥, 3♦)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1525
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.34798905 0.04506594 0.606945  ]
# Raise Ratio: 1.5170
# Action Taken: (<Action.FOLD: 0>, 0)
# ------------------------------------------------------------
#
#
# Round: 23
# Pre-Round Stack: 50
# Post-Round Stack: 65
# Stack delta: 0.3000
# Game states and actions within round:
#
# ------------------------------------------------------------
#
#
# Round: 24
# Pre-Round Stack: 60
# Post-Round Stack: 130
# Stack delta: 1.1667
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 15
# min_bet_to_continue: 5
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 60
# spots_left_bb: 1
# cards: (Q♣, 6♣)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1525
# spots_left_bb: 0
# cards: None
# history: []
#
# ==========================
#
# Action probs: [0.34685192 0.04512148 0.6080266 ]
# Raise Ratio: 1.5171
# Action Taken: (<Action.RAISE: 2>, 18)
#
# State:
# stage: Stage.FLOP
# pot_size: 56
# min_bet_to_continue: 0
# community cards: [6♦, K♥, 5♦]
#
# ====== my player ======
# in_game: True
# stack_size: 37
# spots_left_bb: 1
# cards: (Q♣, 6♣)
# history: [(<Action.RAISE: 2>, 18)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1507
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 18)]
#
# ==========================
#
# Action probs: [2.8382507e-04 9.7037268e-01 2.9343467e-02]
# Raise Ratio: 0.4887
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.TURN
# pot_size: 56
# min_bet_to_continue: 0
# community cards: [6♦, K♥, 5♦, 6♠]
#
# ====== my player ======
# in_game: True
# stack_size: 37
# spots_left_bb: 1
# cards: (Q♣, 6♣)
# history: [(<Action.RAISE: 2>, 18), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1507
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 18), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [1.6970489e-04 4.4865260e-01 5.5117768e-01]
# Raise Ratio: 0.6607
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.RIVER
# pot_size: 56
# min_bet_to_continue: 0
# community cards: [6♦, K♥, 5♦, 6♠, 9♣]
#
# ====== my player ======
# in_game: True
# stack_size: 37
# spots_left_bb: 1
# cards: (Q♣, 6♣)
# history: [(<Action.RAISE: 2>, 18), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 1507
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 18), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
#
# ==========================
#
# Action probs: [1.5974346e-04 3.1242248e-01 6.8741781e-01]
# Raise Ratio: 0.6607
# Action Taken: (<Action.CHECK_CALL: 1>, 0)
#
# State:
# stage: Stage.RIVER
# pot_size: 721
# min_bet_to_continue: 665
# community cards: [6♦, K♥, 5♦, 6♠, 9♣]
#
# ====== my player ======
# in_game: True
# stack_size: 37
# spots_left_bb: 1
# cards: (Q♣, 6♣)
# history: [(<Action.RAISE: 2>, 18), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0)]
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 842
# spots_left_bb: 0
# cards: None
# history: [(<Action.CHECK_CALL: 1>, 18), (<Action.CHECK_CALL: 1>, 0), (<Action.CHECK_CALL: 1>, 0), (<Action.RAISE: 2>, 665)]
#
# ==========================
#
# Action probs: [0.01393599 0.98606396 0.        ]
# Raise Ratio: 0.0513
# Action Taken: (<Action.CHECK_CALL: 1>, 37)
# ------------------------------------------------------------
#
#
# Round: 25
# Pre-Round Stack: 120
# Post-Round Stack: 0
# Stack delta: -1.0000
# Game states and actions within round:
#
#
# State:
# stage: Stage.PREFLOP
# pot_size: 578
# min_bet_to_continue: 558
# community cards: []
#
# ====== my player ======
# in_game: True
# stack_size: 120
# spots_left_bb: 0
# cards: (A♠, 10♥)
# history: []
# my_player_action: None
# =========================
#
# ==== other players =====
# in_game: True
# stack_size: 902
# spots_left_bb: 1
# cards: None
# history: [(<Action.RAISE: 2>, 558)]
#
# ==========================
#
# Action probs: [0.8408698 0.1591302 0.       ]
# Raise Ratio: 0.2076
# Action Taken: (<Action.CHECK_CALL: 1>, 120)
# ------------------------------------------------------------
