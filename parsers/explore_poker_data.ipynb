# %%
import os
import sys
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter, defaultdict
from typing import List, Dict, Tuple

# Add the parent directory to sys.path so we can import our modules
sys.path.append(os.path.abspath('..'))

# Import our parsing modules
from parsers.parse_pluribus_hands import parse_all_pluribus_hands, PokerHand
from parsers.extract_game_states import extract_player_game_states, extract_all_hands_game_states
from Poker.core.card import Card, Rank, Suit
from Poker.core.action import Action
from Poker.core.gamestage import Stage
from Poker.agents.game_state import GameState

# Configure plot style
plt.style.use('ggplot')
sns.set(font_scale=1.2)
plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# ## 1. Load and Parse Poker Hands
#
# First, we'll load the Pluribus hand history files and parse them into structured objects.

# %%
# Define the paths to the Pluribus hand files
# You can use just the 100 folder for quick testing, or all folders for full analysis
# pluribus_dir = "/Users/huram-abi/Desktop/PokerRL/pluribus/100"  # Just one folder
pluribus_dir = "/Users/huram-abi/Desktop/PokerRL/pluribus"  # All folders

# Parse the hands (this might take a while for the full dataset)
print("Parsing poker hands...")
hands = parse_all_pluribus_hands(pluribus_dir)
print(f"Parsed {len(hands)} hands")

# Sample a few hands to explore
sample_hands = random.sample(hands, min(5, len(hands)))

# Display basic info about the first sample hand
print("\nSample hand information:")
hand = sample_hands[0]
print(f"Hand ID: {hand.hand_id}")
print(f"Players: {hand.players}")
print(f"Blinds: {hand.blinds}")
print(f"Community cards: {hand.community_cards}")
print(f"Number of actions: {len(hand.actions)}")
print(f"Starting stacks: {hand.starting_stacks}")
print(f"Finishing stacks: {hand.finishing_stacks}")
# Out:
# Parsing poker hands...
# Parsed 10000 hands
#
# Sample hand information:
# Hand ID: 166
# Players: ['MrOrange', 'Pluribus', 'ORen', 'Hattori', 'MrBlue', 'Bill']
# Blinds: [50, 100, 0, 0, 0, 0]
# Community cards: [K♦, J♦, 10♠, 8♠, 8♦]
# Number of actions: 12
# Starting stacks: [10000, 10000, 10000, 10000, 10000, 10000]
# Finishing stacks: [9950, 10525, 10000, 10000, 9525, 10000]

# %% [markdown]
# Extract and Analyze Game States

# %%
help(pluribus_states[0])
# Out:
# Help on GameState in module Poker.agents.game_state object:
#
# class GameState(builtins.object)
#  |  GameState(stage: Poker.core.gamestage.Stage, community_cards: List[Poker.core.card.Card], pot_size: int, min_bet_to_continue: int, my_player: Poker.agents.game_state.Player, other_players: List[Poker.agents.game_state.Player], my_player_action: Optional[Tuple[Poker.core.action.Action, int]], core_game=None, apply_visibility_rules: bool = True)
#  |
#  |  Represents a game state where "my_player" is about to take an action.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, stage: Poker.core.gamestage.Stage, community_cards: List[Poker.core.card.Card], pot_size: int, min_bet_to_continue: int, my_player: Poker.agents.game_state.Player, other_players: List[Poker.agents.game_state.Player], my_player_action: Optional[Tuple[Poker.core.action.Action, int]], core_game=None, apply_visibility_rules: bool = True)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  get_community_hand_strength(self)
#  |      Returns the hand strength of the community hand with respect to all possible hands.
#  |
#  |  get_effective_turns(self)
#  |
#  |  get_hand_strength(self)
#  |      Returns the hand strength of the hand with respect to all possible hands.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  compute_hand_strength(cards: List[Poker.core.card.Card])
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
# Extract game states for Pluribus
print("Extracting game states for Pluribus...")
pluribus_states = extract_player_game_states(hands, "Pluribus")
print(f"Extracted {len(pluribus_states)} game states for Pluribus")

# Display basic info about a few states
print("\nSample game states:")
for i, state in enumerate(pluribus_states):
    if hasattr(state, 'hand_id'):
        print(f"Game state {i+1} (Hand {state.hand_id}):")
    else:
        print(f"Game state {i+1}:")
    print(f"  Stage: {state.stage.name}")
    print(f"  Community cards: {state.community_cards}")
    print(f"  My cards: {state.my_player.cards}")
    print(f"  Pot size: {state.pot_size}")
    print(f"  Action taken: {state.my_player_action}")
    print(f"  stack: {state.my_player.stack_size}")
    print()
# Out:
# Extracting game states for Pluribus...
# Extracted 15169 game states for Pluribus
#
# Sample game states:
# Game state 1 (Hand 0):
#   Stage: RIVER
#   Community cards: [2♦, 10♣, A♣, 5♦, Q♦]
#   My cards: (7♠, A♠)
#   Pot size: 350
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 2 (Hand 0):
#   Stage: RIVER
#   Community cards: [2♦, 10♣, A♣, 5♦, Q♦]
#   My cards: (7♠, A♠)
#   Pot size: 813
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 3 (Hand 0):
#   Stage: RIVER
#   Community cards: [2♦, 10♣, A♣, 5♦, Q♦]
#   My cards: (7♠, A♠)
#   Pot size: 1013
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 4 (Hand 0):
#   Stage: RIVER
#   Community cards: [2♦, 10♣, A♣, 5♦, Q♦]
#   My cards: (7♠, A♠)
#   Pot size: 1213
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 5 (Hand 0):
#   Stage: RIVER
#   Community cards: [4♦, 8♣, J♣, 2♥, 8♥]
#   My cards: (4♠, 7♠)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 6 (Hand 0):
#   Stage: TURN
#   Community cards: [J♦, 6♣, 6♦, 9♦]
#   My cards: (Q♠, A♠)
#   Pot size: 375
#   Action taken: (<Action.RAISE: 2>, 675)
#   My stack: 10000
#
# Game state 7 (Hand 0):
#   Stage: TURN
#   Community cards: [J♦, 6♣, 6♦, 9♦]
#   My cards: (Q♠, A♠)
#   Pot size: 1250
#   Action taken: (<Action.RAISE: 2>, 375)
#   My stack: 10000
#
# Game state 8 (Hand 0):
#   Stage: TURN
#   Community cards: [J♦, 6♣, 6♦, 9♦]
#   My cards: (Q♠, A♠)
#   Pot size: 1825
#   Action taken: (<Action.RAISE: 2>, 1125)
#   My stack: 10000
#
# Game state 9 (Hand 0):
#   Stage: RIVER
#   Community cards: [4♦, 9♦, Q♠, A♠, 7♠]
#   My cards: (6♠, 4♣)
#   Pot size: 475
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 10 (Hand 0):
#   Stage: RIVER
#   Community cards: [7♣, 9♦, 3♥, 3♣, 5♣]
#   My cards: (10♥, 7♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 11 (Hand 0):
#   Stage: FLOP
#   Community cards: [J♥, K♣, 4♥]
#   My cards: (9♥, 3♠)
#   Pot size: 400
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 12 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♣, Q♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 13 (Hand 0):
#   Stage: RIVER
#   Community cards: [5♦, K♦, A♠, 5♥, 6♥]
#   My cards: (K♣, 8♦)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 14 (Hand 0):
#   Stage: RIVER
#   Community cards: [5♦, K♦, A♠, 5♥, 6♥]
#   My cards: (K♣, 8♦)
#   Pot size: 575
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15 (Hand 0):
#   Stage: RIVER
#   Community cards: [5♦, K♦, A♠, 5♥, 6♥]
#   My cards: (K♣, 8♦)
#   Pot size: 775
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 16 (Hand 0):
#   Stage: RIVER
#   Community cards: [5♦, K♦, A♠, 5♥, 6♥]
#   My cards: (K♣, 8♦)
#   Pot size: 975
#   Action taken: (<Action.RAISE: 2>, 250)
#   My stack: 10000
#
# Game state 17 (Hand 0):
#   Stage: RIVER
#   Community cards: [Q♠, 9♣, 4♠, A♠, 8♦]
#   My cards: (J♥, 5♦)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 18 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♣, 6♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 19 (Hand 0):
#   Stage: RIVER
#   Community cards: [A♠, K♥, J♠, 8♠, 7♠]
#   My cards: (4♠, 3♠)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 20 (Hand 0):
#   Stage: FLOP
#   Community cards: [6♠, 7♥, 2♦]
#   My cards: (5♦, 10♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 21 (Hand 0):
#   Stage: RIVER
#   Community cards: [K♦, Q♥, 3♣, 2♠, 2♥]
#   My cards: (4♠, 7♣)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 22 (Hand 0):
#   Stage: TURN
#   Community cards: [10♥, 7♣, 7♠, Q♠]
#   My cards: (2♠, 6♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 23 (Hand 0):
#   Stage: FLOP
#   Community cards: [K♥, 7♠, 3♥]
#   My cards: (8♥, 10♠)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 24 (Hand 0):
#   Stage: RIVER
#   Community cards: [Q♠, 7♥, 5♠, 4♥, 7♣]
#   My cards: (2♦, J♣)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 25 (Hand 0):
#   Stage: RIVER
#   Community cards: [Q♣, K♦, 6♦, 4♦, K♣]
#   My cards: (10♠, 8♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 26 (Hand 0):
#   Stage: TURN
#   Community cards: [10♥, A♦, K♣, J♠]
#   My cards: (3♦, A♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 27 (Hand 0):
#   Stage: FLOP
#   Community cards: [J♥, 3♣, 6♣]
#   My cards: (10♠, Q♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 28 (Hand 0):
#   Stage: FLOP
#   Community cards: [J♥, 3♣, 6♣]
#   My cards: (10♠, Q♥)
#   Pot size: 575
#   Action taken: (<Action.RAISE: 2>, 250)
#   My stack: 10000
#
# Game state 29 (Hand 0):
#   Stage: FLOP
#   Community cards: [J♥, 3♣, 6♣]
#   My cards: (10♠, Q♥)
#   Pot size: 1575
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 30 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♥, 3♠)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 31 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♣, 8♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 32 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (10♦, 8♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 33 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♥, 10♦)
#   Pot size: 400
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 34 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♥, 10♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 35 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♥, K♦)
#   Pot size: 370
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 36 (Hand 0):
#   Stage: FLOP
#   Community cards: [Q♦, 5♠, A♦]
#   My cards: (J♦, 2♥)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 37 (Hand 0):
#   Stage: FLOP
#   Community cards: [K♥, 4♣, 10♥]
#   My cards: (Q♥, 7♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 38 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (Q♦, 6♦)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 39 (Hand 0):
#   Stage: RIVER
#   Community cards: [9♠, A♠, Q♣, 5♣, 6♠]
#   My cards: (A♥, 7♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 40 (Hand 0):
#   Stage: RIVER
#   Community cards: [9♠, A♠, Q♣, 5♣, 6♠]
#   My cards: (A♥, 7♣)
#   Pot size: 575
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 41 (Hand 0):
#   Stage: RIVER
#   Community cards: [9♠, A♠, Q♣, 5♣, 6♠]
#   My cards: (A♥, 7♣)
#   Pot size: 1050
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 42 (Hand 0):
#   Stage: RIVER
#   Community cards: [9♠, A♠, Q♣, 5♣, 6♠]
#   My cards: (A♥, 7♣)
#   Pot size: 2087
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 43 (Hand 0):
#   Stage: TURN
#   Community cards: [8♦, 7♦, 9♥, J♥]
#   My cards: (J♠, 6♠)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 250)
#   My stack: 10000
#
# Game state 44 (Hand 0):
#   Stage: TURN
#   Community cards: [8♦, 7♦, 9♥, J♥]
#   My cards: (J♠, 6♠)
#   Pot size: 800
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 45 (Hand 0):
#   Stage: TURN
#   Community cards: [8♦, 7♦, 9♥, J♥]
#   My cards: (J♠, 6♠)
#   Pot size: 1275
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 46 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (10♠, Q♠)
#   Pot size: 1075
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 47 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (5♠, 2♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 48 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♠, 2♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 49 (Hand 0):
#   Stage: RIVER
#   Community cards: [Q♣, 7♦, A♣, 8♠, J♦]
#   My cards: (K♦, 5♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 50 (Hand 0):
#   Stage: TURN
#   Community cards: [Q♣, 5♦, J♠, 7♦]
#   My cards: (8♥, 4♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 51 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♥, 4♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 52 (Hand 0):
#   Stage: RIVER
#   Community cards: [3♠, K♣, 5♥, 6♥, 8♥]
#   My cards: (K♦, K♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 53 (Hand 0):
#   Stage: RIVER
#   Community cards: [3♠, K♣, 5♥, 6♥, 8♥]
#   My cards: (K♦, K♥)
#   Pot size: 575
#   Action taken: (<Action.RAISE: 2>, 250)
#   My stack: 10000
#
# Game state 54 (Hand 0):
#   Stage: RIVER
#   Community cards: [3♠, K♣, 5♥, 6♥, 8♥]
#   My cards: (K♦, K♥)
#   Pot size: 1025
#   Action taken: (<Action.RAISE: 2>, 500)
#   My stack: 10000
#
# Game state 55 (Hand 0):
#   Stage: RIVER
#   Community cards: [3♠, K♣, 5♥, 6♥, 8♥]
#   My cards: (K♦, K♥)
#   Pot size: 1725
#   Action taken: (<Action.RAISE: 2>, 1000)
#   My stack: 10000
#
# Game state 56 (Hand 0):
#   Stage: RIVER
#   Community cards: [5♠, 2♣, A♠, K♣, 2♦]
#   My cards: (J♠, A♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 250)
#   My stack: 10000
#
# Game state 57 (Hand 0):
#   Stage: RIVER
#   Community cards: [5♠, 2♣, A♠, K♣, 2♦]
#   My cards: (J♠, A♥)
#   Pot size: 600
#   Action taken: (<Action.RAISE: 2>, 275)
#   My stack: 10000
#
# Game state 58 (Hand 0):
#   Stage: RIVER
#   Community cards: [5♠, 2♣, A♠, K♣, 2♦]
#   My cards: (J♠, A♥)
#   Pot size: 1075
#   Action taken: (<Action.RAISE: 2>, 2200)
#   My stack: 10000
#
# Game state 59 (Hand 0):
#   Stage: RIVER
#   Community cards: [5♠, 2♣, A♠, K♣, 2♦]
#   My cards: (J♠, A♥)
#   Pot size: 3475
#   Action taken: (<Action.RAISE: 2>, 7275)
#   My stack: 10000
#
# Game state 60 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♦, 10♦)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 61 (Hand 0):
#   Stage: RIVER
#   Community cards: [7♦, 5♥, 9♦, 7♣, Q♥]
#   My cards: (6♣, 7♠)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 62 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♠, A♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 63 (Hand 0):
#   Stage: RIVER
#   Community cards: [4♦, 8♠, A♦, Q♣, 2♦]
#   My cards: (7♥, 3♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 64 (Hand 0):
#   Stage: RIVER
#   Community cards: [7♦, A♣, J♥, 2♦, 10♦]
#   My cards: (10♣, 10♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 65 (Hand 0):
#   Stage: RIVER
#   Community cards: [7♦, A♣, J♥, 2♦, 10♦]
#   My cards: (10♣, 10♥)
#   Pot size: 575
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 66 (Hand 0):
#   Stage: RIVER
#   Community cards: [7♦, A♣, J♥, 2♦, 10♦]
#   My cards: (10♣, 10♥)
#   Pot size: 775
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 67 (Hand 0):
#   Stage: RIVER
#   Community cards: [7♦, A♣, J♥, 2♦, 10♦]
#   My cards: (10♣, 10♥)
#   Pot size: 975
#   Action taken: (<Action.RAISE: 2>, 250)
#   My stack: 10000
#
# Game state 68 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♣, 10♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 69 (Hand 0):
#   Stage: RIVER
#   Community cards: [2♥, 8♥, K♠, 5♣, J♠]
#   My cards: (2♠, 10♣)
#   Pot size: 1000
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 70 (Hand 0):
#   Stage: FLOP
#   Community cards: [6♥, 5♦, J♣]
#   My cards: (Q♦, 2♥)
#   Pot size: 975
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 71 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♠, 10♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 72 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♦, 7♠)
#   Pot size: 400
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 73 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♠, Q♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 74 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♥, 4♥)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 75 (Hand 0):
#   Stage: RIVER
#   Community cards: [5♥, A♠, 10♠, J♣, 7♦]
#   My cards: (3♠, 6♠)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 76 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (5♣, K♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 77 (Hand 0):
#   Stage: RIVER
#   Community cards: [J♥, 7♠, 4♠, J♦, K♥]
#   My cards: (4♣, K♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 78 (Hand 0):
#   Stage: RIVER
#   Community cards: [J♥, 7♠, 4♠, J♦, K♥]
#   My cards: (4♣, K♣)
#   Pot size: 575
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 79 (Hand 0):
#   Stage: RIVER
#   Community cards: [J♥, 7♠, 4♠, J♦, K♥]
#   My cards: (4♣, K♣)
#   Pot size: 775
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 80 (Hand 0):
#   Stage: RIVER
#   Community cards: [J♥, 7♠, 4♠, J♦, K♥]
#   My cards: (4♣, K♣)
#   Pot size: 1115
#   Action taken: (<Action.RAISE: 2>, 730)
#   My stack: 10000
#
# Game state 81 (Hand 0):
#   Stage: RIVER
#   Community cards: [4♣, 7♣, A♦, A♠, J♥]
#   My cards: (6♥, 6♦)
#   Pot size: 350
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 82 (Hand 0):
#   Stage: RIVER
#   Community cards: [4♣, 7♣, A♦, A♠, J♥]
#   My cards: (6♥, 6♦)
#   Pot size: 550
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 83 (Hand 0):
#   Stage: RIVER
#   Community cards: [4♣, 7♣, A♦, A♠, J♥]
#   My cards: (6♥, 6♦)
#   Pot size: 750
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 84 (Hand 0):
#   Stage: RIVER
#   Community cards: [4♣, 7♣, A♦, A♠, J♥]
#   My cards: (6♥, 6♦)
#   Pot size: 950
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 85 (Hand 0):
#   Stage: RIVER
#   Community cards: [9♠, J♦, 3♥, 8♦, A♥]
#   My cards: (10♠, 9♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 86 (Hand 0):
#   Stage: RIVER
#   Community cards: [9♠, J♦, 3♥, 8♦, A♥]
#   My cards: (10♠, 9♥)
#   Pot size: 575
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 87 (Hand 0):
#   Stage: RIVER
#   Community cards: [9♠, J♦, 3♥, 8♦, A♥]
#   My cards: (10♠, 9♥)
#   Pot size: 775
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 88 (Hand 0):
#   Stage: RIVER
#   Community cards: [9♠, J♦, 3♥, 8♦, A♥]
#   My cards: (10♠, 9♥)
#   Pot size: 975
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 89 (Hand 0):
#   Stage: TURN
#   Community cards: [10♠, J♣, A♣, A♦]
#   My cards: (2♠, K♦)
#   Pot size: 390
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 90 (Hand 0):
#   Stage: FLOP
#   Community cards: [2♣, 9♦, 4♥]
#   My cards: (J♦, 9♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 91 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (J♠, K♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 92 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (J♠, K♥)
#   Pot size: 1275
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 93 (Hand 0):
#   Stage: TURN
#   Community cards: [4♥, 7♥, 4♣, 3♥]
#   My cards: (5♦, 10♥)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 94 (Hand 0):
#   Stage: FLOP
#   Community cards: [8♠, 9♦, 9♣]
#   My cards: (A♠, 8♥)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 95 (Hand 0):
#   Stage: TURN
#   Community cards: [10♣, K♦, 5♥, 6♠]
#   My cards: (3♠, 8♦)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 96 (Hand 0):
#   Stage: RIVER
#   Community cards: [9♠, 8♠, 10♥, A♣, 7♣]
#   My cards: (7♦, 9♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 97 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♠, 7♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 98 (Hand 0):
#   Stage: TURN
#   Community cards: [9♣, 3♠, 7♣, 5♣]
#   My cards: (9♠, 6♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 99 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♣, 9♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 100 (Hand 0):
#   Stage: RIVER
#   Community cards: [2♠, 8♥, 2♣, Q♣, 4♦]
#   My cards: (K♥, 3♦)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 101 (Hand 0):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♠, 7♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 102 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♠, A♣)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 103 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♥, 9♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 104 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♥, 6♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 105 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♦, 9♥)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 106 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♦, K♦)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 107 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (A♠, 3♠)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 108 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (A♠, 3♠)
#   Pot size: 1300
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 109 (Hand 1):
#   Stage: TURN
#   Community cards: [4♥, A♥, 8♦, J♠]
#   My cards: (J♦, 9♦)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 110 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♥, 8♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 111 (Hand 1):
#   Stage: FLOP
#   Community cards: [K♣, 2♠, 4♦]
#   My cards: (6♥, 3♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 112 (Hand 1):
#   Stage: TURN
#   Community cards: [8♣, A♦, 7♣, 7♠]
#   My cards: (J♠, A♠)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 113 (Hand 1):
#   Stage: TURN
#   Community cards: [8♣, A♦, 7♣, 7♠]
#   My cards: (J♠, A♠)
#   Pot size: 1225
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 114 (Hand 1):
#   Stage: TURN
#   Community cards: [8♣, A♦, 7♣, 7♠]
#   My cards: (J♠, A♠)
#   Pot size: 1425
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 115 (Hand 1):
#   Stage: TURN
#   Community cards: [8♣, A♦, 7♣, 7♠]
#   My cards: (J♠, A♠)
#   Pot size: 1625
#   Action taken: (<Action.RAISE: 2>, 1800)
#   My stack: 10000
#
# Game state 116 (Hand 1):
#   Stage: TURN
#   Community cards: [J♣, 2♣, 4♥, 3♣]
#   My cards: (A♣, A♥)
#   Pot size: 375
#   Action taken: (<Action.RAISE: 2>, 675)
#   My stack: 10000
#
# Game state 117 (Hand 1):
#   Stage: TURN
#   Community cards: [J♣, 2♣, 4♥, 3♣]
#   My cards: (A♣, A♥)
#   Pot size: 1250
#   Action taken: (<Action.RAISE: 2>, 375)
#   My stack: 10000
#
# Game state 118 (Hand 1):
#   Stage: TURN
#   Community cards: [J♣, 2♣, 4♥, 3♣]
#   My cards: (A♣, A♥)
#   Pot size: 1825
#   Action taken: (<Action.RAISE: 2>, 1125)
#   My stack: 10000
#
# Game state 119 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♠, J♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 120 (Hand 1):
#   Stage: RIVER
#   Community cards: [K♦, A♥, 8♣, 9♥, K♣]
#   My cards: (4♣, J♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 121 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♦, K♠)
#   Pot size: 400
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 122 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♠, 6♠)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 123 (Hand 1):
#   Stage: RIVER
#   Community cards: [6♥, 9♦, 8♥, 7♥, A♥]
#   My cards: (2♣, 8♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 124 (Hand 1):
#   Stage: FLOP
#   Community cards: [8♦, A♠, 5♦]
#   My cards: (9♥, 6♣)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 125 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (8♥, 4♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 126 (Hand 1):
#   Stage: TURN
#   Community cards: [2♥, Q♠, Q♦, 8♠]
#   My cards: (K♣, 5♠)
#   Pot size: 370
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 127 (Hand 1):
#   Stage: TURN
#   Community cards: [A♥, 2♠, Q♣, A♦]
#   My cards: (2♣, 7♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 128 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♦, K♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 129 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♣, A♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 130 (Hand 1):
#   Stage: RIVER
#   Community cards: [8♥, 4♠, K♣, A♠, K♦]
#   My cards: (Q♦, 8♠)
#   Pot size: 400
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 131 (Hand 1):
#   Stage: FLOP
#   Community cards: [6♦, Q♦, 6♣]
#   My cards: (7♥, 3♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 132 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (K♣, 3♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 133 (Hand 1):
#   Stage: RIVER
#   Community cards: [8♠, 7♥, 7♦, J♣, 6♠]
#   My cards: (2♣, 3♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 134 (Hand 1):
#   Stage: TURN
#   Community cards: [2♠, A♦, 3♦, 2♥]
#   My cards: (8♣, K♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 135 (Hand 1):
#   Stage: TURN
#   Community cards: [K♥, A♥, K♠, 8♦]
#   My cards: (3♠, 7♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 136 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♣, K♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 250)
#   My stack: 10000
#
# Game state 137 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (4♥, J♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 138 (Hand 1):
#   Stage: TURN
#   Community cards: [4♥, 8♥, 5♦, 4♣]
#   My cards: (K♣, J♣)
#   Pot size: 360
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 139 (Hand 1):
#   Stage: TURN
#   Community cards: [4♥, 8♥, 5♦, 4♣]
#   My cards: (K♣, J♣)
#   Pot size: 760
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 140 (Hand 1):
#   Stage: TURN
#   Community cards: [4♥, 8♥, 5♦, 4♣]
#   My cards: (K♣, J♣)
#   Pot size: 1300
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 141 (Hand 1):
#   Stage: FLOP
#   Community cards: [K♥, 10♥, 4♣]
#   My cards: (6♥, 7♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 142 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (J♥, 7♥)
#   Pot size: 370
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 143 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (Q♣, 9♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 144 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♣, 3♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 145 (Hand 1):
#   Stage: RIVER
#   Community cards: [J♥, Q♣, Q♠, 5♣, 4♥]
#   My cards: (2♠, 8♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 146 (Hand 1):
#   Stage: RIVER
#   Community cards: [5♥, J♠, 5♠, 2♣, 3♠]
#   My cards: (Q♣, 6♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 147 (Hand 1):
#   Stage: RIVER
#   Community cards: [3♠, 5♠, J♠, 6♥, 2♣]
#   My cards: (5♥, A♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 148 (Hand 1):
#   Stage: RIVER
#   Community cards: [3♠, 5♠, J♠, 6♥, 2♣]
#   My cards: (5♥, A♣)
#   Pot size: 475
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 149 (Hand 1):
#   Stage: RIVER
#   Community cards: [3♠, 5♠, J♠, 6♥, 2♣]
#   My cards: (5♥, A♣)
#   Pot size: 675
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 150 (Hand 1):
#   Stage: RIVER
#   Community cards: [3♠, 5♠, J♠, 6♥, 2♣]
#   My cards: (5♥, A♣)
#   Pot size: 875
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 151 (Hand 1):
#   Stage: RIVER
#   Community cards: [3♠, 5♠, J♠, 6♥, 2♣]
#   My cards: (5♥, A♣)
#   Pot size: 1425
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 152 (Hand 1):
#   Stage: RIVER
#   Community cards: [2♥, 8♥, 3♣, Q♦, K♣]
#   My cards: (J♣, 5♣)
#   Pot size: 250
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 153 (Hand 1):
#   Stage: TURN
#   Community cards: [7♠, 9♣, 10♣, 2♣]
#   My cards: (7♥, K♥)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 154 (Hand 1):
#   Stage: RIVER
#   Community cards: [5♠, 6♠, 7♦, 10♠, 6♥]
#   My cards: (Q♥, 7♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 155 (Hand 1):
#   Stage: RIVER
#   Community cards: [5♠, 6♠, 7♦, 10♠, 6♥]
#   My cards: (Q♥, 7♥)
#   Pot size: 550
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 156 (Hand 1):
#   Stage: RIVER
#   Community cards: [5♠, 6♠, 7♦, 10♠, 6♥]
#   My cards: (Q♥, 7♥)
#   Pot size: 750
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 157 (Hand 1):
#   Stage: RIVER
#   Community cards: [5♠, 6♠, 7♦, 10♠, 6♥]
#   My cards: (Q♥, 7♥)
#   Pot size: 950
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 158 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (A♥, 2♣)
#   Pot size: 1100
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 159 (Hand 1):
#   Stage: FLOP
#   Community cards: [10♦, 2♦, 4♦]
#   My cards: (Q♦, 7♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 160 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♥, 9♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 161 (Hand 1):
#   Stage: RIVER
#   Community cards: [5♦, K♥, 9♥, K♠, 8♠]
#   My cards: (A♠, 2♠)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 162 (Hand 1):
#   Stage: TURN
#   Community cards: [6♣, 9♥, 10♦, K♠]
#   My cards: (A♠, 7♦)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 163 (Hand 1):
#   Stage: FLOP
#   Community cards: [2♠, 9♦, Q♣]
#   My cards: (10♥, 4♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 164 (Hand 1):
#   Stage: RIVER
#   Community cards: [K♣, Q♠, K♠, 10♠, 4♣]
#   My cards: (5♣, K♦)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 165 (Hand 1):
#   Stage: RIVER
#   Community cards: [10♠, A♠, J♠, Q♠, 10♦]
#   My cards: (K♦, 9♦)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 166 (Hand 1):
#   Stage: RIVER
#   Community cards: [10♠, A♠, J♠, Q♠, 10♦]
#   My cards: (K♦, 9♦)
#   Pot size: 550
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 167 (Hand 1):
#   Stage: RIVER
#   Community cards: [10♠, A♠, J♠, Q♠, 10♦]
#   My cards: (K♦, 9♦)
#   Pot size: 1200
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 168 (Hand 1):
#   Stage: RIVER
#   Community cards: [10♠, A♠, J♠, Q♠, 10♦]
#   My cards: (K♦, 9♦)
#   Pot size: 2462
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 169 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♠, 2♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 170 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♦, 7♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 171 (Hand 1):
#   Stage: FLOP
#   Community cards: [A♥, Q♥, 3♣]
#   My cards: (Q♦, A♠)
#   Pot size: 350
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 172 (Hand 1):
#   Stage: FLOP
#   Community cards: [A♥, Q♥, 3♣]
#   My cards: (Q♦, A♠)
#   Pot size: 650
#   Action taken: (<Action.RAISE: 2>, 375)
#   My stack: 10000
#
# Game state 173 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♣, Q♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 174 (Hand 1):
#   Stage: RIVER
#   Community cards: [5♦, 5♠, 6♦, 10♠, 9♥]
#   My cards: (J♦, 8♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 175 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♠, 9♣)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 176 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (Q♣, 10♦)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 177 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (Q♣, 10♦)
#   Pot size: 1350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 178 (Hand 1):
#   Stage: TURN
#   Community cards: [6♦, 8♠, 8♦, J♣]
#   My cards: (3♦, Q♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 179 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (4♦, 3♣)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 180 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♣, 4♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 181 (Hand 1):
#   Stage: TURN
#   Community cards: [6♥, 9♥, 5♠, K♣]
#   My cards: (7♣, 4♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 182 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (4♥, 9♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 183 (Hand 1):
#   Stage: RIVER
#   Community cards: [6♥, 9♠, 10♥, 3♣, 8♦]
#   My cards: (2♦, 10♦)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 184 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (10♦, J♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 185 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (10♦, J♣)
#   Pot size: 1070
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 186 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (8♣, 9♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 187 (Hand 1):
#   Stage: RIVER
#   Community cards: [6♣, 2♠, A♠, 3♣, 8♦]
#   My cards: (4♥, 4♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 188 (Hand 1):
#   Stage: FLOP
#   Community cards: [10♦, 6♠, 2♥]
#   My cards: (9♥, 8♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 189 (Hand 1):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♣, A♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 190 (Hand 2):
#   Stage: RIVER
#   Community cards: [2♣, 7♠, 2♥, 9♥, 5♠]
#   My cards: (6♦, J♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 191 (Hand 2):
#   Stage: RIVER
#   Community cards: [J♣, 9♣, 2♥, 10♥, 7♣]
#   My cards: (K♦, 8♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 192 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♠, Q♦, 3♠, 5♦, 7♦]
#   My cards: (9♣, 10♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 193 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (J♥, A♠)
#   Pot size: 250
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 194 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♥, 4♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 195 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (J♦, 9♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 196 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (5♦, A♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 197 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♦, 4♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 198 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♥, 2♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 199 (Hand 2):
#   Stage: FLOP
#   Community cards: [7♦, K♥, K♠]
#   My cards: (8♠, A♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 200 (Hand 2):
#   Stage: RIVER
#   Community cards: [10♠, A♥, A♦, J♠, 10♦]
#   My cards: (2♠, 2♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 201 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♦, 5♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 202 (Hand 2):
#   Stage: FLOP
#   Community cards: [3♥, 9♦, 4♥]
#   My cards: (3♦, 5♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 203 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♠, 3♠, A♣, 3♣, 8♥]
#   My cards: (Q♥, 3♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 204 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♣, J♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 205 (Hand 2):
#   Stage: RIVER
#   Community cards: [J♥, J♠, 3♥, 10♥, 7♣]
#   My cards: (6♣, 8♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 206 (Hand 2):
#   Stage: TURN
#   Community cards: [Q♦, 9♠, J♣, 9♥]
#   My cards: (4♣, A♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 207 (Hand 2):
#   Stage: TURN
#   Community cards: [Q♦, 9♠, J♣, 9♥]
#   My cards: (4♣, A♣)
#   Pot size: 550
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 208 (Hand 2):
#   Stage: TURN
#   Community cards: [Q♦, 9♠, J♣, 9♥]
#   My cards: (4♣, A♣)
#   Pot size: 750
#   Action taken: (<Action.RAISE: 2>, 125)
#   My stack: 10000
#
# Game state 209 (Hand 2):
#   Stage: RIVER
#   Community cards: [10♣, 5♠, 10♠, 4♣, 8♣]
#   My cards: (J♠, 6♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 210 (Hand 2):
#   Stage: RIVER
#   Community cards: [10♥, 8♦, J♣, 5♠, K♣]
#   My cards: (3♣, 4♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 211 (Hand 2):
#   Stage: FLOP
#   Community cards: [4♥, 9♠, J♣]
#   My cards: (Q♣, 6♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 212 (Hand 2):
#   Stage: RIVER
#   Community cards: [J♥, A♠, 6♥, 9♠, A♥]
#   My cards: (2♣, 10♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 213 (Hand 2):
#   Stage: FLOP
#   Community cards: [8♦, 10♣, 2♦]
#   My cards: (3♥, 8♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 214 (Hand 2):
#   Stage: RIVER
#   Community cards: [4♠, 2♣, 8♥, 6♦, 10♣]
#   My cards: (6♣, 8♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 215 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♥, A♦, 8♣, 10♥, 10♠]
#   My cards: (6♠, 5♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 216 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (5♠, K♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 217 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♣, A♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 218 (Hand 2):
#   Stage: TURN
#   Community cards: [K♥, 2♣, 9♥, 10♦]
#   My cards: (J♣, 8♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 219 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♥, K♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 220 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♥, 10♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 221 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♣, J♦)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 222 (Hand 2):
#   Stage: TURN
#   Community cards: [3♠, 7♣, 8♦, 3♦]
#   My cards: (J♦, 8♠)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 223 (Hand 2):
#   Stage: RIVER
#   Community cards: [10♠, K♣, J♥, 9♣, A♦]
#   My cards: (K♦, 9♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 224 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♦, Q♠, 6♠, 10♥, 3♥]
#   My cards: (J♦, K♠)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 225 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♦, Q♠, 6♠, 10♥, 3♥]
#   My cards: (J♦, K♠)
#   Pot size: 550
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 226 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♦, Q♠, 6♠, 10♥, 3♥]
#   My cards: (J♦, K♠)
#   Pot size: 750
#   Action taken: (<Action.RAISE: 2>, 450)
#   My stack: 10000
#
# Game state 227 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♦, Q♠, 6♠, 10♥, 3♥]
#   My cards: (J♦, K♠)
#   Pot size: 1400
#   Action taken: (<Action.RAISE: 2>, 1012)
#   My stack: 10000
#
# Game state 228 (Hand 2):
#   Stage: TURN
#   Community cards: [J♠, 4♠, Q♥, Q♦]
#   My cards: (A♠, 10♦)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 229 (Hand 2):
#   Stage: TURN
#   Community cards: [J♠, 4♠, Q♥, Q♦]
#   My cards: (A♠, 10♦)
#   Pot size: 550
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 230 (Hand 2):
#   Stage: TURN
#   Community cards: [J♠, 4♠, Q♥, Q♦]
#   My cards: (A♠, 10♦)
#   Pot size: 1625
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 231 (Hand 2):
#   Stage: TURN
#   Community cards: [J♠, 4♠, Q♥, Q♦]
#   My cards: (A♠, 10♦)
#   Pot size: 4125
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 232 (Hand 2):
#   Stage: RIVER
#   Community cards: [5♣, 8♦, 3♦, 2♣, 9♦]
#   My cards: (3♥, Q♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 233 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♥, 7♠, 6♣, 3♣, K♣]
#   My cards: (K♥, Q♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 234 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♥, 7♠, 6♣, 3♣, K♣]
#   My cards: (K♥, Q♣)
#   Pot size: 550
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 235 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♥, 7♠, 6♣, 3♣, K♣]
#   My cards: (K♥, Q♣)
#   Pot size: 750
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 236 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♥, 7♠, 6♣, 3♣, K♣]
#   My cards: (K♥, Q♣)
#   Pot size: 950
#   Action taken: (<Action.RAISE: 2>, 337)
#   My stack: 10000
#
# Game state 237 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (K♦, 9♦)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 238 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (K♦, 9♦)
#   Pot size: 1065
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 239 (Hand 2):
#   Stage: FLOP
#   Community cards: [2♥, 9♣, 8♥]
#   My cards: (5♦, 4♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 240 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (5♥, 9♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 241 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♣, 8♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 242 (Hand 2):
#   Stage: TURN
#   Community cards: [8♣, 3♦, 5♥, 6♣]
#   My cards: (A♦, J♠)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 243 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (K♣, 5♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 244 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (5♠, 9♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 245 (Hand 2):
#   Stage: TURN
#   Community cards: [5♣, 9♠, 7♣, 3♥]
#   My cards: (8♣, 4♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 246 (Hand 2):
#   Stage: FLOP
#   Community cards: [3♦, Q♠, 10♥]
#   My cards: (8♥, A♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 247 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♦, K♦)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 248 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (4♠, K♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 249 (Hand 2):
#   Stage: FLOP
#   Community cards: [Q♦, 2♣, 3♥]
#   My cards: (8♥, Q♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 250 (Hand 2):
#   Stage: FLOP
#   Community cards: [Q♦, 2♣, 3♥]
#   My cards: (8♥, Q♥)
#   Pot size: 550
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 251 (Hand 2):
#   Stage: RIVER
#   Community cards: [J♥, 5♥, 7♦, 8♥, 10♣]
#   My cards: (2♦, K♠)
#   Pot size: 250
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 252 (Hand 2):
#   Stage: RIVER
#   Community cards: [7♣, 7♠, 6♥, 4♣, 8♠]
#   My cards: (2♥, 2♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 253 (Hand 2):
#   Stage: FLOP
#   Community cards: [A♣, 4♠, 9♦]
#   My cards: (Q♠, 7♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 254 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♠, 5♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 255 (Hand 2):
#   Stage: RIVER
#   Community cards: [4♣, J♦, 5♦, 8♥, 10♥]
#   My cards: (K♦, 5♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 256 (Hand 2):
#   Stage: RIVER
#   Community cards: [5♦, 6♠, J♠, A♣, 6♥]
#   My cards: (4♥, 4♠)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 257 (Hand 2):
#   Stage: RIVER
#   Community cards: [5♦, 6♠, J♠, A♣, 6♥]
#   My cards: (4♥, 4♠)
#   Pot size: 550
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 258 (Hand 2):
#   Stage: RIVER
#   Community cards: [5♦, 6♠, J♠, A♣, 6♥]
#   My cards: (4♥, 4♠)
#   Pot size: 750
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 259 (Hand 2):
#   Stage: RIVER
#   Community cards: [5♦, 6♠, J♠, A♣, 6♥]
#   My cards: (4♥, 4♠)
#   Pot size: 1175
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 260 (Hand 2):
#   Stage: FLOP
#   Community cards: [3♥, 4♥, 10♣]
#   My cards: (6♠, 9♥)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 261 (Hand 2):
#   Stage: FLOP
#   Community cards: [A♣, A♦, 5♥]
#   My cards: (A♥, 4♣)
#   Pot size: 380
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 262 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (3♦, 3♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 263 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♣, K♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 264 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (A♦, 5♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 265 (Hand 2):
#   Stage: RIVER
#   Community cards: [J♦, 8♠, 3♣, K♥, 7♦]
#   My cards: (4♥, 2♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 266 (Hand 2):
#   Stage: RIVER
#   Community cards: [9♦, A♥, Q♦, J♣, Q♣]
#   My cards: (6♥, K♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 267 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (Q♣, 5♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 268 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (A♠, 5♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 269 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♥, Q♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 270 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♦, K♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 271 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (10♦, 7♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 272 (Hand 2):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (5♦, 6♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 273 (Hand 3):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (J♥, Q♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 274 (Hand 3):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (5♣, 2♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 275 (Hand 3):
#   Stage: RIVER
#   Community cards: [7♦, 2♥, 9♠, 10♥, 3♥]
#   My cards: (Q♥, 8♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 276 (Hand 3):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (8♥, 9♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 277 (Hand 3):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (5♣, 3♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 278 (Hand 3):
#   Stage: RIVER
#   Community cards: [10♠, 2♣, Q♣, Q♠, 9♥]
#   My cards: (7♥, J♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 279 (Hand 3):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (8♥, K♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 280 (Hand 3):
#   Stage: TURN
#   Community cards: [4♥, 2♥, 7♥, 4♣]
#   My cards: (7♣, 8♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 281 (Hand 3):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♣, Q♦)
#   Pot size: 150
# ...
#   Community cards: []
#   My cards: (A♣, A♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 15080 (Hand 255):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (K♦, 6♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15081 (Hand 255):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♠, 7♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15082 (Hand 256):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♥, 4♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15083 (Hand 256):
#   Stage: RIVER
#   Community cards: [K♠, Q♣, 3♣, 9♦, 4♥]
#   My cards: (2♣, 5♣)
#   Pot size: 375
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15084 (Hand 256):
#   Stage: RIVER
#   Community cards: [K♠, Q♣, 3♣, 9♦, 4♥]
#   My cards: (2♣, 5♣)
#   Pot size: 475
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15085 (Hand 256):
#   Stage: RIVER
#   Community cards: [K♠, Q♣, 3♣, 9♦, 4♥]
#   My cards: (2♣, 5♣)
#   Pot size: 825
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15086 (Hand 256):
#   Stage: RIVER
#   Community cards: [K♠, Q♣, 3♣, 9♦, 4♥]
#   My cards: (2♣, 5♣)
#   Pot size: 925
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15087 (Hand 256):
#   Stage: RIVER
#   Community cards: [K♠, Q♣, 3♣, 9♦, 4♥]
#   My cards: (2♣, 5♣)
#   Pot size: 1125
#   Action taken: (<Action.RAISE: 2>, 1500)
#   My stack: 10000
#
# Game state 15088 (Hand 257):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (8♥, 10♠)
#   Pot size: 1050
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15089 (Hand 257):
#   Stage: TURN
#   Community cards: [5♥, 8♠, A♦, K♦]
#   My cards: (7♣, J♣)
#   Pot size: 400
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15090 (Hand 258):
#   Stage: TURN
#   Community cards: [3♥, 6♦, 4♣, Q♠]
#   My cards: (3♦, 9♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15091 (Hand 258):
#   Stage: FLOP
#   Community cards: [2♠, A♠, 9♠]
#   My cards: (4♥, 4♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 15092 (Hand 258):
#   Stage: FLOP
#   Community cards: [2♠, A♠, 9♠]
#   My cards: (4♥, 4♣)
#   Pot size: 1500
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15093 (Hand 258):
#   Stage: FLOP
#   Community cards: [2♠, A♠, 9♠]
#   My cards: (4♥, 4♣)
#   Pot size: 1700
#   Action taken: (<Action.RAISE: 2>, 575)
#   My stack: 10000
#
# Game state 15094 (Hand 259):
#   Stage: TURN
#   Community cards: [J♠, 10♦, A♣, K♦]
#   My cards: (4♣, 4♠)
#   Pot size: 360
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15095 (Hand 259):
#   Stage: TURN
#   Community cards: [J♠, 10♦, A♣, K♦]
#   My cards: (4♣, 4♠)
#   Pot size: 1455
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15096 (Hand 259):
#   Stage: RIVER
#   Community cards: [K♥, 6♥, 6♦, 5♣, 10♠]
#   My cards: (4♠, 4♦)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 15097 (Hand 259):
#   Stage: RIVER
#   Community cards: [K♥, 6♥, 6♦, 5♣, 10♠]
#   My cards: (4♠, 4♦)
#   Pot size: 550
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15098 (Hand 259):
#   Stage: RIVER
#   Community cards: [K♥, 6♥, 6♦, 5♣, 10♠]
#   My cards: (4♠, 4♦)
#   Pot size: 750
#   Action taken: (<Action.RAISE: 2>, 112)
#   My stack: 10000
#
# Game state 15099 (Hand 259):
#   Stage: RIVER
#   Community cards: [K♥, 6♥, 6♦, 5♣, 10♠]
#   My cards: (4♠, 4♦)
#   Pot size: 1062
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15100 (Hand 260):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (J♠, K♠)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 15101 (Hand 260):
#   Stage: RIVER
#   Community cards: [4♦, 10♠, J♦, 7♥, 3♠]
#   My cards: (4♥, 8♠)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15102 (Hand 261):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (4♣, 5♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15103 (Hand 261):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♠, Q♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15104 (Hand 262):
#   Stage: TURN
#   Community cards: [7♣, 8♥, 9♣, 4♣]
#   My cards: (10♠, Q♥)
#   Pot size: 375
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15105 (Hand 262):
#   Stage: TURN
#   Community cards: [7♣, 8♥, 9♣, 4♣]
#   My cards: (10♠, Q♥)
#   Pot size: 475
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15106 (Hand 262):
#   Stage: TURN
#   Community cards: [7♣, 8♥, 9♣, 4♣]
#   My cards: (10♠, Q♥)
#   Pot size: 675
#   Action taken: (<Action.RAISE: 2>, 250)
#   My stack: 10000
#
# Game state 15107 (Hand 262):
#   Stage: RIVER
#   Community cards: [J♣, 3♦, 2♠, 2♦, J♥]
#   My cards: (4♣, 4♠)
#   Pot size: 425
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15108 (Hand 262):
#   Stage: RIVER
#   Community cards: [J♣, 3♦, 2♠, 2♦, J♥]
#   My cards: (4♣, 4♠)
#   Pot size: 525
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15109 (Hand 262):
#   Stage: RIVER
#   Community cards: [J♣, 3♦, 2♠, 2♦, J♥]
#   My cards: (4♣, 4♠)
#   Pot size: 775
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15110 (Hand 262):
#   Stage: RIVER
#   Community cards: [J♣, 3♦, 2♠, 2♦, J♥]
#   My cards: (4♣, 4♠)
#   Pot size: 875
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15111 (Hand 262):
#   Stage: RIVER
#   Community cards: [J♣, 3♦, 2♠, 2♦, J♥]
#   My cards: (4♣, 4♠)
#   Pot size: 1752
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15112 (Hand 262):
#   Stage: RIVER
#   Community cards: [J♣, 3♦, 2♠, 2♦, J♥]
#   My cards: (4♣, 4♠)
#   Pot size: 1852
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15113 (Hand 263):
#   Stage: FLOP
#   Community cards: [8♥, 10♠, K♦]
#   My cards: (7♠, K♥)
#   Pot size: 400
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15114 (Hand 263):
#   Stage: FLOP
#   Community cards: [4♠, J♠, 9♦]
#   My cards: (3♠, Q♠)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 300)
#   My stack: 10000
#
# Game state 15115 (Hand 263):
#   Stage: FLOP
#   Community cards: [4♠, J♠, 9♦]
#   My cards: (3♠, Q♠)
#   Pot size: 550
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15116 (Hand 263):
#   Stage: FLOP
#   Community cards: [4♠, J♠, 9♦]
#   My cards: (3♠, Q♠)
#   Pot size: 1051
#   Action taken: (<Action.RAISE: 2>, 1102)
#   My stack: 10000
#
# Game state 15117 (Hand 264):
#   Stage: RIVER
#   Community cards: [5♠, 2♠, K♠, 2♥, J♣]
#   My cards: (8♦, A♣)
#   Pot size: 475
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15118 (Hand 264):
#   Stage: RIVER
#   Community cards: [8♠, 6♦, 6♥, K♠, K♥]
#   My cards: (A♥, 4♠)
#   Pot size: 350
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15119 (Hand 265):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♥, 10♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15120 (Hand 265):
#   Stage: FLOP
#   Community cards: [8♠, 9♣, J♠]
#   My cards: (Q♦, 3♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15121 (Hand 266):
#   Stage: FLOP
#   Community cards: [K♥, 9♠, 5♥]
#   My cards: (A♠, 3♠)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 200)
#   My stack: 10000
#
# Game state 15122 (Hand 266):
#   Stage: FLOP
#   Community cards: [K♥, 9♠, 5♥]
#   My cards: (A♠, 3♠)
#   Pot size: 550
#   Action taken: (<Action.RAISE: 2>, 450)
#   My stack: 10000
#
# Game state 15123 (Hand 266):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (A♥, 9♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15124 (Hand 267):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (K♠, J♦)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 287)
#   My stack: 10000
#
# Game state 15125 (Hand 267):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (K♠, J♦)
#   Pot size: 1737
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15126 (Hand 267):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (8♦, 10♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15127 (Hand 268):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (9♥, Q♠)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15128 (Hand 268):
#   Stage: RIVER
#   Community cards: [5♠, Q♣, A♠, 3♠, 3♣]
#   My cards: (J♠, J♦)
#   Pot size: 375
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15129 (Hand 268):
#   Stage: RIVER
#   Community cards: [5♠, Q♣, A♠, 3♠, 3♣]
#   My cards: (J♠, J♦)
#   Pot size: 475
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15130 (Hand 268):
#   Stage: RIVER
#   Community cards: [5♠, Q♣, A♠, 3♠, 3♣]
#   My cards: (J♠, J♦)
#   Pot size: 675
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15131 (Hand 268):
#   Stage: RIVER
#   Community cards: [5♠, Q♣, A♠, 3♠, 3♣]
#   My cards: (J♠, J♦)
#   Pot size: 1150
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15132 (Hand 268):
#   Stage: RIVER
#   Community cards: [5♠, Q♣, A♠, 3♠, 3♣]
#   My cards: (J♠, J♦)
#   Pot size: 1250
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15133 (Hand 269):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (2♠, 5♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15134 (Hand 269):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (10♠, J♦)
#   Pot size: 400
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15135 (Hand 270):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (8♣, 4♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15136 (Hand 270):
#   Stage: TURN
#   Community cards: [Q♥, K♠, 7♠, J♦]
#   My cards: (K♥, 5♣)
#   Pot size: 475
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15137 (Hand 271):
#   Stage: RIVER
#   Community cards: [4♠, 2♣, J♠, 9♥, J♥]
#   My cards: (J♣, 8♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 287)
#   My stack: 10000
#
# Game state 15138 (Hand 271):
#   Stage: RIVER
#   Community cards: [4♠, 2♣, J♠, 9♥, J♥]
#   My cards: (J♣, 8♣)
#   Pot size: 637
#   Action taken: (<Action.RAISE: 2>, 312)
#   My stack: 10000
#
# Game state 15139 (Hand 271):
#   Stage: RIVER
#   Community cards: [4♠, 2♣, J♠, 9♥, J♥]
#   My cards: (J♣, 8♣)
#   Pot size: 1149
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15140 (Hand 271):
#   Stage: RIVER
#   Community cards: [4♠, 2♣, J♠, 9♥, J♥]
#   My cards: (J♣, 8♣)
#   Pot size: 1349
#   Action taken: (<Action.RAISE: 2>, 936)
#   My stack: 10000
#
# Game state 15141 (Hand 272):
#   Stage: FLOP
#   Community cards: [8♥, J♣, 4♣]
#   My cards: (7♦, 4♠)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15142 (Hand 273):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (8♥, 3♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15143 (Hand 274):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (4♣, 9♥)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15144 (Hand 275):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (8♦, J♦)
#   Pot size: 400
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15145 (Hand 276):
#   Stage: TURN
#   Community cards: [3♣, 6♥, A♣, 2♥]
#   My cards: (J♦, 6♣)
#   Pot size: 375
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15146 (Hand 277):
#   Stage: FLOP
#   Community cards: [8♥, 7♦, 10♥]
#   My cards: (Q♦, A♥)
#   Pot size: 360
#   Action taken: (<Action.RAISE: 2>, 750)
#   My stack: 10000
#
# Game state 15147 (Hand 277):
#   Stage: FLOP
#   Community cards: [8♥, 7♦, 10♥]
#   My cards: (Q♦, A♥)
#   Pot size: 1310
#   Action taken: (<Action.RAISE: 2>, 825)
#   My stack: 10000
#
# Game state 15148 (Hand 277):
#   Stage: FLOP
#   Community cards: [8♥, 7♦, 10♥]
#   My cards: (Q♦, A♥)
#   Pot size: 4510
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15149 (Hand 278):
#   Stage: FLOP
#   Community cards: [6♥, 3♦, 5♥]
#   My cards: (Q♦, 7♠)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15150 (Hand 279):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (7♥, 8♠)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15151 (Hand 280):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (5♦, 6♦)
#   Pot size: 400
#   Action taken: (<Action.RAISE: 2>, 937)
#   My stack: 10000
#
# Game state 15152 (Hand 281):
#   Stage: FLOP
#   Community cards: [K♥, J♥, 9♣]
#   My cards: (2♥, J♣)
#   Pot size: 472
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15153 (Hand 282):
#   Stage: RIVER
#   Community cards: [6♦, 7♦, 5♠, 8♣, J♠]
#   My cards: (4♣, 2♦)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15154 (Hand 283):
#   Stage: TURN
#   Community cards: [8♥, 9♠, Q♠, 5♠]
#   My cards: (6♦, 5♣)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15155 (Hand 284):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (8♠, J♥)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15156 (Hand 285):
#   Stage: RIVER
#   Community cards: [J♣, 3♥, 5♥, 9♦, 9♠]
#   My cards: (J♠, Q♣)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 250)
#   My stack: 10000
#
# Game state 15157 (Hand 285):
#   Stage: RIVER
#   Community cards: [J♣, 3♥, 5♥, 9♦, 9♠]
#   My cards: (J♠, Q♣)
#   Pot size: 600
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15158 (Hand 285):
#   Stage: RIVER
#   Community cards: [J♣, 3♥, 5♥, 9♦, 9♠]
#   My cards: (J♠, Q♣)
#   Pot size: 800
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15159 (Hand 285):
#   Stage: RIVER
#   Community cards: [J♣, 3♥, 5♥, 9♦, 9♠]
#   My cards: (J♠, Q♣)
#   Pot size: 1000
#   Action taken: (<Action.RAISE: 2>, 412)
#   My stack: 10000
#
# Game state 15160 (Hand 286):
#   Stage: RIVER
#   Community cards: [8♥, 8♣, 2♥, 3♠, J♠]
#   My cards: (9♣, Q♠)
#   Pot size: 450
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15161 (Hand 286):
#   Stage: RIVER
#   Community cards: [8♥, 8♣, 2♥, 3♠, J♠]
#   My cards: (9♣, Q♠)
#   Pot size: 650
#   Action taken: (<Action.RAISE: 2>, 600)
#   My stack: 10000
#
# Game state 15162 (Hand 286):
#   Stage: RIVER
#   Community cards: [8♥, 8♣, 2♥, 3♠, J♠]
#   My cards: (9♣, Q♠)
#   Pot size: 1450
#   Action taken: (<Action.CHECK_CALL: 1>, None)
#   My stack: 10000
#
# Game state 15163 (Hand 286):
#   Stage: RIVER
#   Community cards: [8♥, 8♣, 2♥, 3♠, J♠]
#   My cards: (9♣, Q♠)
#   Pot size: 1650
#   Action taken: (<Action.RAISE: 2>, 900)
#   My stack: 10000
#
# Game state 15164 (Hand 286):
#   Stage: RIVER
#   Community cards: [8♥, 8♣, 2♥, 3♠, J♠]
#   My cards: (9♣, Q♠)
#   Pot size: 6150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15165 (Hand 287):
#   Stage: FLOP
#   Community cards: [2♠, K♠, 3♦]
#   My cards: (6♥, J♥)
#   Pot size: 1072
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15166 (Hand 288):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (K♠, 10♥)
#   Pot size: 360
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15167 (Hand 289):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (10♠, A♥)
#   Pot size: 150
#   Action taken: (<Action.RAISE: 2>, 225)
#   My stack: 10000
#
# Game state 15168 (Hand 290):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (J♥, 7♦)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
#
# Game state 15169 (Hand 291):
#   Stage: PREFLOP
#   Community cards: []
#   My cards: (6♥, 5♣)
#   Pot size: 150
#   Action taken: (<Action.FOLD: 0>, None)
#   My stack: 10000
